# %% [markdown]
# ### Task 1

# %% [markdown]
# Task 1:
# 1.
# Install Jupyter notebook and run the first program and share the screenshot of the output.

# %%
#Screen shot of Task 1_Q2

from IPython.display import Image
Image("/Users/shivroopa/ML Master/Jupyter installation Screenshot.png", width=600, height=600)

# %% [markdown]
# 2.
# Write a program which will find all such numbers which are divisible by 7 but are not a multiple of 5, between 2000 and 3200 (both included). The numbers obtained should be printed in a comma-separated sequence on a single line.

# %%
#empty list
number = []
#for loop to run through 2000 to 3000 inclusive
for i in range(2000, 3201):
    s = str(i)
    if (int(s)%7==0) and (int(s)%5!=0):
        number.append(s)        
print(', '.join(number))
# Out:
# 2002, 2009, 2016, 2023, 2037, 2044, 2051, 2058, 2072, 2079, 2086, 2093, 2107, 2114, 2121, 2128, 2142, 2149, 2156, 2163, 2177, 2184, 2191, 2198, 2212, 2219, 2226, 2233, 2247, 2254, 2261, 2268, 2282, 2289, 2296, 2303, 2317, 2324, 2331, 2338, 2352, 2359, 2366, 2373, 2387, 2394, 2401, 2408, 2422, 2429, 2436, 2443, 2457, 2464, 2471, 2478, 2492, 2499, 2506, 2513, 2527, 2534, 2541, 2548, 2562, 2569, 2576, 2583, 2597, 2604, 2611, 2618, 2632, 2639, 2646, 2653, 2667, 2674, 2681, 2688, 2702, 2709, 2716, 2723, 2737, 2744, 2751, 2758, 2772, 2779, 2786, 2793, 2807, 2814, 2821, 2828, 2842, 2849, 2856, 2863, 2877, 2884, 2891, 2898, 2912, 2919, 2926, 2933, 2947, 2954, 2961, 2968, 2982, 2989, 2996, 3003, 3017, 3024, 3031, 3038, 3052, 3059, 3066, 3073, 3087, 3094, 3101, 3108, 3122, 3129, 3136, 3143, 3157, 3164, 3171, 3178, 3192, 3199

# %%
#Screen shot of Task 1_Q2

from IPython.display import Image
Image("/Users/shivroopa/ML Master/task1_Q2.png", width=700, height=600)

# %% [markdown]
# 3.
# Write a Python program to accept the user's first and last name and then getting them printed in the the reverse order with a space between first name and last name.

# %%
first_name = input('Enter first name: ')
last_name = input('Enter last name: ')
print('\nReversed first and last name: ' + first_name[::-1] + ' ' + last_name[::-1]) #slicing the string which steps backward
# Out:
# Enter first name: Rohan
# Enter last name: Deshmukh
#
# Reversed first and last name: nahoR hkumhseD

# %%
#Screen shot of Task 1_Q3

from IPython.display import Image
Image("/Users/shivroopa/ML Master/task1_Q3.png", width=700, height=600)

# %% [markdown]
# 4.
# Write a Python program to find the volume of a sphere with diameter 12 cm. Formula: V=4/3 * π * r 3

# %%
d = 12
r = d/2
pi = 3.14
vol = (4/3) * pi * (r**3) 
print('Volume of a sphere with diameter 12 cm is: ' + str(vol))
# Out:
# Volume of a sphere with diameter 12 cm is: 904.3199999999999

# %%
#Screen shot of Task 1_Q4

from IPython.display import Image
Image("/Users/shivroopa/ML Master/Task1_Q4.png", width=700, height=600)

# %% [markdown]
# ### Task 2
#
#
# 1.
# Write a program which accepts a sequence of comma-separated numbers from console and generate a list.

# %%
numbers = input('Please enter comma-separated numbers: ') #Console input is always of String type
number_list = numbers.split(',') #split function converts String to List
print('Comma-separated numbers converted to list \n' + str(number_list))
# Out:
# Please enter comma-separated numbers: 39,84,22,10
# Comma-separated numbers converted to list
# ['39', '84', '22', '10']

# %%
#Screen shot of Task 2_Q1

from IPython.display import Image
Image("/Users/shivroopa/ML Master/task2_Q1.png", width=700, height=600)

# %% [markdown]
# 2.
# Create the below pattern using nested for loop in Python.
# *
# **
# ***
# ****
# *****
# ****
# ***
# **
# *

# %%
for i in range(1, 6):
    for j in range(1, i+1):
        print('*', end = '')
    print('\r')

for i in range (5, 0, -1):
    for j in range(0, i -1):
        print("*", end='')
    print("\r")
# Out:
# *
# **
# ***
# ****
# *****
# ****
# ***
# **
# *

# %%
#Screen shot of Task 2_Q2

from IPython.display import Image
Image("/Users/shivroopa/ML Master/task2_Q2.png", width=500, height=500)

# %% [markdown]
# 3.
# Write a Python program to reverse a word after accepting the input from the user. Sample Output:
# Input word: AcadGild
# Output: dilGdacA

# %%
word = input('Please enter a word: ')
print('OutPut: \nThe reversed of "' + word + '" is: ' + word[::-1])
# Out:
# Please enter a word: AcadGild
# OutPut:
# The reversed of "AcadGild" is: dliGdacA

# %%
#Screen shot of Task 2_Q3

from IPython.display import Image
Image("/Users/shivroopa/ML Master/task2_Q3.png", width=500, height=600)

# %% [markdown]
# 4.
# Write a Python Program to print the given string in the format specified in the ​sample output.
# WE, THE PEOPLE OF INDIA, having solemnly resolved to constitute India into a SOVEREIGN, SOCIALIST, SECULAR, DEMOCRATIC REPUBLIC and to secure to all its citizens
# Sample Output:
# WE, THE PEOPLE OF INDIA,
#     having solemnly resolved to constitute India into a SOVEREIGN, !
#             SOCIALIST, SECULAR, DEMOCRATIC REPUBLIC
#              and to secure to all its citizens

# %%
print('WE, THE PEOPLE OF INDIA, \n\thaving solemnly resolved to constitute India into a SOVEREIGN, ! \n\t\tSOCIALIST, SECULAR, DEMOCRATIC \n\t\t REPUBLIC and to secure to all its citizens')
# Out:
# WE, THE PEOPLE OF INDIA,
# 	having solemnly resolved to constitute India into a SOVEREIGN, !
# 		SOCIALIST, SECULAR, DEMOCRATIC
# 		 REPUBLIC and to secure to all its citizens

# %%
#Screen shot of Task 2_Q4

from IPython.display import Image
Image("/Users/shivroopa/ML Master/task2_Q4.png", width=700, height=600)
